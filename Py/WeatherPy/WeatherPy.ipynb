# %% [markdown]
# # WeatherPy: A Spatial Analysis of Global Temperature Trends With Python API calls and Matplotlib Visualizations
# ----

# %%
# Dependencies
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
from citipy import citipy
import random
import requests
import json
from datetime import datetime
from pprint import pprint
import scipy.stats as sts

# OpenWeatherMap API key
from api_keys import open_weather_key as api_key

# %% [markdown]
# ## Generate lists of 2,000 random lat/long locations
# * Generate a list of 2,000 random locations across the range of latitudes (-60 to 90)and longitudes (-180 to 180). Cut latitude at -60 to constrain analysis to habitable southern continents. 2,000 calls are made in a later step to OpenWeatherMap to ensure that data is available for a minimum of 500 cities.

# %%
# Generate list of random lat/long tuples to use in OpenWeatherMap API calls.

lats = []
longs = []
latlongs = []

# Populate lat and long lists with 2,000 random values because approximately 1,000 API calls
# will return blank data in later step.
for i in range(2000):
    lats.append(random.uniform(-60, 90))
    longs.append(random.uniform(-180, 180))

latlongs = list(zip(lats, longs))

# %%
# As an alternative to using lat/longs for OpenWeatherMap API calls, obtain list of cities from citipy library
# and call OpenWeatherMap by city. I chose to use the latlongs list instead to avoid duplicate city name
# like Versailles, France and Versailles, Kentucky.

cities = []
country_codes = []
cities_countries = []

for latlong in latlongs:
    city = citipy.nearest_city(latlong[0], latlong[1]).city_name.capitalize()
    # Call for cities and corresponding country codes until cities_1000 has 1,000 unique cities.
    if (city not in cities and len(cities)<1000):
        cities.append(city)
        country_codes.append(citipy.nearest_city(latlong[0], latlong[1]).country_code.upper())

# Zip cities and country codes into a single list to use in OpenWeatherMap API calls.
cities_countries = zip(cities, country_codes)

# %% [markdown]
# ### Perform API Calls
# * Using the latlongs list, perform 1,000 API calls to OpenWeatherMap to retrieve current weather for each location and build a log.

# %%
# Make a sample API call to OpenWeatherMap to view json structure.
url = "https://api.openweathermap.org/data/2.5/weather?lat=" + str(33.4) + "&lon=" + str(-112) + "&appid=" + api_key
response = requests.get(url).json()
#print(response["dt"])
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 33.4,
#         "lon": -112
#     },
#     "dt": 1603673592,
#     "id": 5296962,
#     "main": {
#         "feels_like": 300.14,
#         "humidity": 30,
#         "pressure": 999,
#         "temp": 300.8,
#         "temp_max": 301.48,
#         "temp_min": 300.37
#     },
#     "name": "Guadalupe",
#     "sys": {
#         "country": "US",
#         "id": 2006351,
#         "sunrise": 1603633259,
#         "sunset": 1603672965,
#         "type": 3
#     },
#     "timezone": -25200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 131,
#         "gust": 2.24,
#         "speed": 0.45
#     }
# }

# %%
# Loop through latlongs list, make calls to OpenWeatherMap api, parse the response, and append to cities_log.

base_url = "http://api.openweathermap.org/data/2.5/weather?"
cities_weather_log = []
city_number = 0

for latlong in latlongs:
    url = base_url + "lat=" + str(latlong[0]) + "&lon=" + str(latlong[1]) + "&appid=" + api_key
    # Use try/except to skip over calls that return no data.
    city_number +=1
    try:
        response = requests.get(url).json()
        date = datetime.utcfromtimestamp(response["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        lat = response["coord"]["lat"]
        long = response["coord"]["lon"]
        city = response["name"]
        country_code = response["sys"]["country"]
        temp = response["main"]["temp"]
        temp = float(temp)*9/5-459.67
        temp = str(round(temp, 1))
        humidity = response["main"]["humidity"]
        wind_speed = response["wind"]["speed"]
        cloudiness = response["clouds"]["all"]
        cities_weather_log.append({"City": city, "Country": country_code, 
                                   "Latitude": lat, "Longitude": long, "Current Temperature": temp,
                                   "Humidity": humidity, "Cloudiness": cloudiness,
                                   "Wind Speed": wind_speed, "Date": date})
        print("City number: " + str(city_number) + "  City name: " + city)
    except (KeyError):
        print("City number: " + str(city_number) + " did not return data.")
# Out:
# City number: 1  City name: Ozona
# City number: 2  City name: Seyfūllīn
# City number: 3 did not return data.
# City number: 4  City name: Sesheke
# City number: 5 did not return data.
# City number: 6  City name: Mweka
# City number: 7 did not return data.
# City number: 8  City name: Bowen
# City number: 9 did not return data.
# City number: 10  City name: Tanjung
# City number: 11 did not return data.
# City number: 12 did not return data.
# City number: 13 did not return data.
# City number: 14 did not return data.
# City number: 15  City name: Tokār
# City number: 16  City name: Celestún
# City number: 17 did not return data.
# City number: 18 did not return data.
# City number: 19 did not return data.
# City number: 20  City name: Rio Brilhante
# City number: 21 did not return data.
# City number: 22 did not return data.
# City number: 23  City name: Sigli
# City number: 24 did not return data.
# City number: 25 did not return data.
# City number: 26  City name: Tahe
# City number: 27  City name: Madre de Dios
# City number: 28 did not return data.
# City number: 29 did not return data.
# City number: 30  City name: Dongargaon
# City number: 31 did not return data.
# City number: 32 did not return data.
# City number: 33 did not return data.
# City number: 34 did not return data.
# City number: 35 did not return data.
# City number: 36 did not return data.
# City number: 37 did not return data.
# City number: 38 did not return data.
# City number: 39 did not return data.
# City number: 40 did not return data.
# City number: 41  City name: Fort Franklin
# City number: 42 did not return data.
# City number: 43  City name: Porgera
# City number: 44  City name: Dukhovnitskoye
# City number: 45  City name: Brezina
# City number: 46 did not return data.
# City number: 47 did not return data.
# City number: 48 did not return data.
# City number: 49 did not return data.
# City number: 50 did not return data.
# City number: 51 did not return data.
# City number: 52 did not return data.
# City number: 53  City name: Ullswater
# City number: 54 did not return data.
# City number: 55 did not return data.
# City number: 56  City name: Nuiqsut
# City number: 57 did not return data.
# City number: 58 did not return data.
# City number: 59  City name: Yazıbaşı
# City number: 60  City name: Northwest
# City number: 61  City name: Sachs Harbour
# City number: 62  City name: Ullal
# City number: 63  City name: Iriba
# City number: 64 did not return data.
# City number: 65 did not return data.
# City number: 66 did not return data.
# City number: 67 did not return data.
# City number: 68 did not return data.
# City number: 69 did not return data.
# City number: 70  City name: Néma
# City number: 71 did not return data.
# City number: 72  City name: Bilibino
# City number: 73 did not return data.
# City number: 74 did not return data.
# City number: 75  City name: Ghardaia Province
# City number: 76 did not return data.
# City number: 77  City name: Khakasiya Republic
# City number: 78  City name: Arizona
# City number: 79 did not return data.
# City number: 80 did not return data.
# City number: 81  City name: Foso
# City number: 82 did not return data.
# City number: 83 did not return data.
# City number: 84  City name: Niger
# City number: 85  City name: Kelibia
# City number: 86  City name: Røst
# City number: 87 did not return data.
# City number: 88 did not return data.
# City number: 89 did not return data.
# City number: 90 did not return data.
# City number: 91 did not return data.
# City number: 92 did not return data.
# City number: 93  City name: Laranja da Terra
# City number: 94 did not return data.
# City number: 95 did not return data.
# City number: 96  City name: -
# City number: 97  City name: Jabal al Gharbi District
# City number: 98 did not return data.
# City number: 99 did not return data.
# City number: 100 did not return data.
# City number: 101 did not return data.
# City number: 102 did not return data.
# City number: 103 did not return data.
# City number: 104 did not return data.
# City number: 105 did not return data.
# City number: 106 did not return data.
# City number: 107  City name: Tymovskoye
# City number: 108 did not return data.
# City number: 109 did not return data.
# City number: 110  City name: Yubzha
# City number: 111 did not return data.
# City number: 112 did not return data.
# City number: 113  City name: Panguna
# City number: 114  City name: Haines
# City number: 115 did not return data.
# City number: 116 did not return data.
# City number: 117 did not return data.
# City number: 118  City name: Dunnigan
# City number: 119 did not return data.
# City number: 120  City name: Goldfields
# City number: 121 did not return data.
# City number: 122 did not return data.
# City number: 123  City name: Ofanleiti
# City number: 124  City name: Jokkmokk
# City number: 125 did not return data.
# City number: 126 did not return data.
# City number: 127  City name: Ghat
# City number: 128  City name: Naj‘ Tinjār
# City number: 129 did not return data.
# City number: 130  City name: Neiafu
# City number: 131 did not return data.
# City number: 132 did not return data.
# City number: 133 did not return data.
# City number: 134 did not return data.
# City number: 135 did not return data.
# City number: 136 did not return data.
# City number: 137 did not return data.
# City number: 138  City name: Boothbay Harbor
# City number: 139 did not return data.
# City number: 140  City name: Kavaratti
# City number: 141  City name: Carauari
# City number: 142 did not return data.
# City number: 143 did not return data.
# City number: 144  City name: Nosy Varika
# City number: 145  City name: Huangtian Nongchang
# City number: 146 did not return data.
# City number: 147  City name: Kismayo
# City number: 148 did not return data.
# City number: 149 did not return data.
# City number: 150 did not return data.
# City number: 151  City name: Potanina
# City number: 152 did not return data.
# City number: 153 did not return data.
# City number: 154 did not return data.
# City number: 155  City name: Stoneville
# City number: 156 did not return data.
# City number: 157  City name: Vel't
# City number: 158 did not return data.
# City number: 159  City name: Bagdarin
# City number: 160  City name: Pahrump
# City number: 161 did not return data.
# City number: 162  City name: Isachsen
# City number: 163 did not return data.
# City number: 164 did not return data.
# City number: 165 did not return data.
# City number: 166 did not return data.
# City number: 167 did not return data.
# City number: 168 did not return data.
# City number: 169 did not return data.
# City number: 170  City name: Nikiski
# City number: 171 did not return data.
# City number: 172  City name: Departamento de Picún Leufú
# City number: 173 did not return data.
# City number: 174  City name: Norman Wells
# City number: 175  City name: Fort Good Hope
# City number: 176 did not return data.
# City number: 177  City name: Discovery
# City number: 178 did not return data.
# City number: 179 did not return data.
# City number: 180  City name: Pine Ridge
# City number: 181 did not return data.
# City number: 182 did not return data.
# City number: 183  City name: Gamboa
# City number: 184  City name: Ross River
# City number: 185  City name: Polyarnyye Zori
# City number: 186 did not return data.
# City number: 187 did not return data.
# City number: 188 did not return data.
# City number: 189 did not return data.
# City number: 190 did not return data.
# City number: 191 did not return data.
# City number: 192  City name: Ruvuma
# City number: 193  City name: Francke
# City number: 194 did not return data.
# City number: 195  City name: Provincia de Antofagasta
# City number: 196 did not return data.
# City number: 197  City name: Perho
# City number: 198  City name: Watson Lake
# City number: 199 did not return data.
# City number: 200 did not return data.
# City number: 201  City name: Navonda
# City number: 202 did not return data.
# City number: 203 did not return data.
# City number: 204 did not return data.
# City number: 205  City name: Richibucto
# City number: 206  City name: Entuziastov
# City number: 207 did not return data.
# City number: 208  City name: Krutinka
# City number: 209 did not return data.
# City number: 210  City name: Whyalla
# City number: 211 did not return data.
# City number: 212  City name: Teribërka
# City number: 213  City name: Merus
# City number: 214 did not return data.
# City number: 215  City name: Uummannaq
# City number: 216 did not return data.
# City number: 217  City name: São Sebastião do Caí
# City number: 218 did not return data.
# City number: 219  City name: Ust'-Ilimsk
# City number: 220 did not return data.
# City number: 221 did not return data.
# City number: 222 did not return data.
# City number: 223 did not return data.
# City number: 224  City name: Emita
# City number: 225 did not return data.
# City number: 226  City name: Dupuy
# City number: 227  City name: Bahamas
# City number: 228 did not return data.
# City number: 229 did not return data.
# City number: 230 did not return data.
# City number: 231 did not return data.
# City number: 232  City name: Aozou
# City number: 233 did not return data.
# City number: 234 did not return data.
# City number: 235  City name: Dingxi
# City number: 236 did not return data.
# City number: 237 did not return data.
# City number: 238 did not return data.
# City number: 239 did not return data.
# City number: 240 did not return data.
# City number: 241  City name: Middlingbank
# City number: 242 did not return data.
# City number: 243 did not return data.
# City number: 244  City name: Shimoni
# City number: 245  City name: Saint Helena
# City number: 246  City name: Uborka
# City number: 247 did not return data.
# City number: 248 did not return data.
# City number: 249  City name: Daintree
# City number: 250 did not return data.
# City number: 251 did not return data.
# City number: 252 did not return data.
# City number: 253  City name: French Southern Territories
# City number: 254  City name: Hollis
# City number: 255  City name: Ko Chang Tai
# City number: 256  City name: Daliburgh
# City number: 257 did not return data.
# City number: 258 did not return data.
# City number: 259 did not return data.
# City number: 260 did not return data.
# City number: 261 did not return data.
# City number: 262 did not return data.
# City number: 263 did not return data.
# City number: 264  City name: Pond Inlet
# City number: 265 did not return data.
# City number: 266 did not return data.
# City number: 267 did not return data.
# City number: 268 did not return data.
# City number: 269 did not return data.
# City number: 270 did not return data.
# City number: 271  City name: Isachsen
# City number: 272  City name: Madaoua
# City number: 273 did not return data.
# City number: 274 did not return data.
# City number: 275  City name: Ad Dilam
# City number: 276 did not return data.
# City number: 277 did not return data.
# City number: 278 did not return data.
# City number: 279 did not return data.
# City number: 280 did not return data.
# City number: 281 did not return data.
# City number: 282  City name: Guarda Mor
# City number: 283 did not return data.
# City number: 284 did not return data.
# City number: 285 did not return data.
# City number: 286  City name: Maradi
# City number: 287 did not return data.
# City number: 288 did not return data.
# City number: 289  City name: Wales
# City number: 290 did not return data.
# City number: 291  City name: Zimov’ye Kezhemskoye
# City number: 292 did not return data.
# City number: 293 did not return data.
# City number: 294 did not return data.
# City number: 295  City name: Puerto Williams
# City number: 296  City name: Khuzdar
# City number: 297 did not return data.
# City number: 298 did not return data.
# City number: 299 did not return data.
# City number: 300 did not return data.
# City number: 301 did not return data.
# City number: 302  City name: Huangshapu
# City number: 303 did not return data.
# City number: 304 did not return data.
# City number: 305  City name: Stanley Mission
# City number: 306 did not return data.
# City number: 307 did not return data.
# City number: 308 did not return data.
# City number: 309 did not return data.
# City number: 310 did not return data.
# City number: 311  City name: Da Lat
# City number: 312  City name: Ust'-Ilimsk
# City number: 313 did not return data.
# City number: 314 did not return data.
# City number: 315  City name: Krasnosel'kup
# City number: 316  City name: Preiļi Municipality
# City number: 317 did not return data.
# City number: 318 did not return data.
# City number: 319 did not return data.
# City number: 320 did not return data.
# City number: 321 did not return data.
# City number: 322  City name: Beiwudu
# City number: 323  City name: Ardmore
# City number: 324 did not return data.
# City number: 325 did not return data.
# City number: 326  City name: Berens Landing
# City number: 327 did not return data.
# City number: 328 did not return data.
# City number: 329 did not return data.
# City number: 330  City name: Charyshskoye
# City number: 331 did not return data.
# City number: 332  City name: Nunavut
# City number: 333 did not return data.
# City number: 334  City name: Tsiigehtchic
# City number: 335 did not return data.
# City number: 336  City name: Khomas
# City number: 337 did not return data.
# City number: 338  City name: Rappang
# City number: 339 did not return data.
# City number: 340 did not return data.
# City number: 341 did not return data.
# City number: 342  City name: Aldama
# City number: 343  City name: Shihezi
# City number: 344 did not return data.
# City number: 345  City name: Padilla de Arriba
# City number: 346 did not return data.
# City number: 347 did not return data.
# City number: 348  City name: Sarmizegetusa
# City number: 349  City name: Arviat
# City number: 350  City name: Aligoundiri
# City number: 351 did not return data.
# City number: 352 did not return data.
# City number: 353 did not return data.
# City number: 354  City name: Wager Bay
# City number: 355 did not return data.
# City number: 356 did not return data.
# City number: 357 did not return data.
# City number: 358 did not return data.
# City number: 359 did not return data.
# City number: 360  City name: Aksu-Ayuly
# City number: 361 did not return data.
# City number: 362 did not return data.
# City number: 363  City name: Pickle Lake
# City number: 364 did not return data.
# City number: 365 did not return data.
# City number: 366 did not return data.
# City number: 367 did not return data.
# City number: 368  City name: Uttarkāshi
# City number: 369 did not return data.
# City number: 370 did not return data.
# City number: 371  City name: Aleutians West
# City number: 372 did not return data.
# City number: 373  City name: Xianshui
# City number: 374  City name: Nukuoro
# City number: 375 did not return data.
# City number: 376 did not return data.
# City number: 377 did not return data.
# City number: 378  City name: Gialo
# City number: 379 did not return data.
# City number: 380 did not return data.
# City number: 381  City name: Bonfim
# City number: 382 did not return data.
# City number: 383 did not return data.
# City number: 384 did not return data.
# City number: 385  City name: Septimus
# City number: 386 did not return data.
# City number: 387  City name: Ponezhukay
# City number: 388 did not return data.
# City number: 389 did not return data.
# City number: 390 did not return data.
# City number: 391 did not return data.
# City number: 392 did not return data.
# City number: 393 did not return data.
# City number: 394 did not return data.
# City number: 395 did not return data.
# City number: 396 did not return data.
# City number: 397 did not return data.
# City number: 398 did not return data.
# City number: 399 did not return data.
# City number: 400  City name: Pangnirtung
# City number: 401 did not return data.
# City number: 402 did not return data.
# City number: 403 did not return data.
# City number: 404 did not return data.
# City number: 405  City name: Juli
# City number: 406 did not return data.
# City number: 407  City name: Erenhot
# City number: 408 did not return data.
# City number: 409 did not return data.
# City number: 410 did not return data.
# City number: 411 did not return data.
# City number: 412 did not return data.
# City number: 413 did not return data.
# City number: 414  City name: Ostān-e Kermānshāh
# City number: 415 did not return data.
# City number: 416  City name: Dahlia
# City number: 417  City name: Sāngola
# City number: 418 did not return data.
# City number: 419 did not return data.
# City number: 420  City name: Old Crow
# City number: 421 did not return data.
# City number: 422  City name: Ulaanhudag
# City number: 423  City name: Algeria
# City number: 424 did not return data.
# City number: 425  City name: Newman
# City number: 426 did not return data.
# City number: 427 did not return data.
# City number: 428 did not return data.
# City number: 429 did not return data.
# City number: 430 did not return data.
# City number: 431 did not return data.
# City number: 432  City name: Funehikimachi-funehiki
# City number: 433 did not return data.
# City number: 434 did not return data.
# City number: 435 did not return data.
# City number: 436 did not return data.
# City number: 437 did not return data.
# City number: 438 did not return data.
# City number: 439  City name: Mbumi
# City number: 440 did not return data.
# City number: 441 did not return data.
# City number: 442  City name: Baker Lake
# City number: 443 did not return data.
# City number: 444 did not return data.
# City number: 445 did not return data.
# City number: 446 did not return data.
# City number: 447 did not return data.
# City number: 448 did not return data.
# City number: 449 did not return data.
# City number: 450  City name: Terenos
# City number: 451 did not return data.
# City number: 452  City name: Manokwari
# City number: 453 did not return data.
# City number: 454 did not return data.
# City number: 455  City name: Srednekolymsk
# City number: 456 did not return data.
# City number: 457 did not return data.
# City number: 458 did not return data.
# City number: 459  City name: Dikson
# City number: 460 did not return data.
# City number: 461 did not return data.
# City number: 462  City name: River Gee County
# City number: 463  City name: Maleevsk
# City number: 464 did not return data.
# City number: 465 did not return data.
# City number: 466 did not return data.
# City number: 467  City name: Drovyanoy
# City number: 468  City name: Leksula
# City number: 469 did not return data.
# City number: 470 did not return data.
# City number: 471 did not return data.
# City number: 472 did not return data.
# City number: 473 did not return data.
# City number: 474 did not return data.
# City number: 475 did not return data.
# City number: 476 did not return data.
# City number: 477  City name: Xinghe Chengguanzhen
# City number: 478 did not return data.
# City number: 479  City name: Guajará Açu
# City number: 480 did not return data.
# City number: 481 did not return data.
# City number: 482 did not return data.
# City number: 483  City name: Diplo
# City number: 484  City name: De Aar
# City number: 485 did not return data.
# City number: 486  City name: Santa Monica
# City number: 487 did not return data.
# City number: 488 did not return data.
# City number: 489 did not return data.
# City number: 490 did not return data.
# City number: 491  City name: Mossamedes
# City number: 492 did not return data.
# City number: 493 did not return data.
# City number: 494 did not return data.
# City number: 495 did not return data.
# City number: 496 did not return data.
# City number: 497  City name: Boû Demgha
# City number: 498 did not return data.
# City number: 499 did not return data.
# City number: 500 did not return data.
# City number: 501 did not return data.
# City number: 502 did not return data.
# City number: 503 did not return data.
# City number: 504  City name: Hechuan
# City number: 505  City name: Gyigang
# City number: 506  City name: Condamine
# City number: 507  City name: Kuchāman
# City number: 508 did not return data.
# City number: 509  City name: Mungret
# City number: 510 did not return data.
# City number: 511 did not return data.
# City number: 512 did not return data.
# City number: 513 did not return data.
# City number: 514 did not return data.
# City number: 515  City name: Watsa
# City number: 516  City name: Palana
# City number: 517  City name: Nagapattinam
# City number: 518 did not return data.
# City number: 519 did not return data.
# City number: 520  City name: Cardonal
# City number: 521  City name: Gjoa Haven
# City number: 522 did not return data.
# City number: 523 did not return data.
# City number: 524 did not return data.
# City number: 525 did not return data.
# City number: 526 did not return data.
# City number: 527 did not return data.
# City number: 528 did not return data.
# City number: 529 did not return data.
# City number: 530 did not return data.
# City number: 531  City name: Bissett
# City number: 532 did not return data.
# City number: 533 did not return data.
# City number: 534 did not return data.
# City number: 535 did not return data.
# City number: 536 did not return data.
# City number: 537 did not return data.
# City number: 538 did not return data.
# City number: 539 did not return data.
# City number: 540  City name: Eastpoint
# City number: 541 did not return data.
# City number: 542 did not return data.
# City number: 543 did not return data.
# City number: 544 did not return data.
# City number: 545 did not return data.
# City number: 546 did not return data.
# City number: 547 did not return data.
# City number: 548 did not return data.
# City number: 549  City name: Special Region of Papua
# City number: 550 did not return data.
# City number: 551  City name: Telén
# City number: 552  City name: Durania
# City number: 553 did not return data.
# City number: 554  City name: Cerro de Ortega
# City number: 555 did not return data.
# City number: 556 did not return data.
# City number: 557  City name: Pischlach
# City number: 558 did not return data.
# City number: 559 did not return data.
# City number: 560 did not return data.
# City number: 561 did not return data.
# City number: 562 did not return data.
# City number: 563 did not return data.
# City number: 564 did not return data.
# City number: 565 did not return data.
# City number: 566  City name: Aripuanã
# City number: 567 did not return data.
# City number: 568 did not return data.
# City number: 569 did not return data.
# City number: 570 did not return data.
# City number: 571 did not return data.
# City number: 572  City name: Paind do Araguaia
# City number: 573 did not return data.
# City number: 574  City name: Riberalta
# City number: 575 did not return data.
# City number: 576 did not return data.
# City number: 577 did not return data.
# City number: 578 did not return data.
# City number: 579 did not return data.
# City number: 580 did not return data.
# City number: 581  City name: Ezbet el-Burg
# City number: 582 did not return data.
# City number: 583  City name: Jiwani
# City number: 584  City name: Ranua
# City number: 585 did not return data.
# City number: 586  City name: Borgo Casale
# City number: 587 did not return data.
# City number: 588 did not return data.
# City number: 589 did not return data.
# City number: 590 did not return data.
# City number: 591 did not return data.
# City number: 592 did not return data.
# City number: 593 did not return data.
# City number: 594  City name: Baie de Henne
# City number: 595 did not return data.
# City number: 596  City name: Svetlyy
# City number: 597 did not return data.
# City number: 598 did not return data.
# City number: 599  City name: Russellville
# City number: 600 did not return data.
# City number: 601 did not return data.
# City number: 602 did not return data.
# City number: 603 did not return data.
# City number: 604 did not return data.
# City number: 605  City name: Senillosa
# City number: 606  City name: Fereydūnkenār
# City number: 607  City name: Clyde River
# City number: 608  City name: Coober Pedy
# City number: 609 did not return data.
# City number: 610  City name: Caledonia
# City number: 611  City name: Ola
# City number: 612 did not return data.
# City number: 613 did not return data.
# City number: 614 did not return data.
# City number: 615 did not return data.
# City number: 616 did not return data.
# City number: 617 did not return data.
# City number: 618 did not return data.
# City number: 619  City name: Zahedan
# City number: 620 did not return data.
# City number: 621 did not return data.
# City number: 622 did not return data.
# City number: 623 did not return data.
# City number: 624 did not return data.
# City number: 625 did not return data.
# City number: 626 did not return data.
# City number: 627  City name: Irtyshskiy
# City number: 628 did not return data.
# City number: 629 did not return data.
# City number: 630  City name: Akhmīm
# City number: 631 did not return data.
# City number: 632 did not return data.
# City number: 633 did not return data.
# City number: 634 did not return data.
# City number: 635 did not return data.
# City number: 636 did not return data.
# City number: 637  City name: Lavia
# City number: 638  City name: Munda
# City number: 639 did not return data.
# City number: 640 did not return data.
# City number: 641 did not return data.
# City number: 642 did not return data.
# City number: 643  City name: Türkmenbaşy
# City number: 644 did not return data.
# City number: 645 did not return data.
# City number: 646  City name: Ibiaí
# City number: 647 did not return data.
# City number: 648  City name: Leran
# City number: 649  City name: Miðgarðar
# City number: 650 did not return data.
# City number: 651  City name: Aībak
# City number: 652 did not return data.
# City number: 653  City name: Princeville
# City number: 654 did not return data.
# City number: 655 did not return data.
# City number: 656  City name: Koslan
# City number: 657  City name: Winnett
# City number: 658 did not return data.
# City number: 659 did not return data.
# City number: 660 did not return data.
# City number: 661  City name: Nordland
# City number: 662  City name: Ataka-shimmachi
# City number: 663  City name: Sarongan
# City number: 664 did not return data.
# City number: 665 did not return data.
# City number: 666  City name: Brodokalmak
# City number: 667 did not return data.
# City number: 668  City name: Cáceres
# City number: 669 did not return data.
# City number: 670 did not return data.
# City number: 671 did not return data.
# City number: 672  City name: Zhigansk
# City number: 673 did not return data.
# City number: 674 did not return data.
# City number: 675  City name: Mórrope
# City number: 676 did not return data.
# City number: 677 did not return data.
# City number: 678 did not return data.
# City number: 679 did not return data.
# City number: 680 did not return data.
# City number: 681 did not return data.
# City number: 682 did not return data.
# City number: 683  City name: Tokār
# City number: 684 did not return data.
# City number: 685 did not return data.
# City number: 686 did not return data.
# City number: 687 did not return data.
# City number: 688 did not return data.
# City number: 689 did not return data.
# City number: 690 did not return data.
# City number: 691 did not return data.
# City number: 692  City name: Rivière-Rouge
# City number: 693 did not return data.
# City number: 694 did not return data.
# City number: 695 did not return data.
# City number: 696 did not return data.
# City number: 697  City name: Guizengeard
# City number: 698  City name: Port Saint John's
# City number: 699  City name: Anna Regina
# City number: 700 did not return data.
# City number: 701 did not return data.
# City number: 702 did not return data.
# City number: 703 did not return data.
# City number: 704 did not return data.
# City number: 705  City name: Taksimo
# City number: 706 did not return data.
# City number: 707 did not return data.
# City number: 708 did not return data.
# City number: 709  City name: Ternovka
# City number: 710 did not return data.
# City number: 711  City name: Naghadeh
# City number: 712  City name: Maloye Ganyushkino
# City number: 713 did not return data.
# City number: 714  City name: Strugi Krasnye
# City number: 715  City name: Myeik
# City number: 716 did not return data.
# City number: 717 did not return data.
# City number: 718  City name: Beeghly Heights
# City number: 719  City name: Zyryanka
# City number: 720  City name: Naujaat
# City number: 721 did not return data.
# City number: 722 did not return data.
# City number: 723 did not return data.
# City number: 724  City name: Daweishan
# City number: 725  City name: Cachimbo
# City number: 726 did not return data.
# City number: 727 did not return data.
# City number: 728 did not return data.
# City number: 729 did not return data.
# City number: 730  City name: Departamento de Presidente Hayes
# City number: 731  City name: Umaoya
# City number: 732 did not return data.
# City number: 733 did not return data.
# City number: 734 did not return data.
# City number: 735  City name: Sandy Point
# City number: 736  City name: Port-Gentil
# City number: 737 did not return data.
# City number: 738 did not return data.
# City number: 739  City name: Tegul'det
# City number: 740 did not return data.
# City number: 741 did not return data.
# City number: 742 did not return data.
# City number: 743 did not return data.
# City number: 744  City name: Maimará
# City number: 745 did not return data.
# City number: 746  City name: Angetu
# City number: 747 did not return data.
# City number: 748 did not return data.
# City number: 749 did not return data.
# City number: 750 did not return data.
# City number: 751 did not return data.
# City number: 752 did not return data.
# City number: 753 did not return data.
# City number: 754  City name: Shintō
# City number: 755 did not return data.
# City number: 756  City name: Tainan
# City number: 757 did not return data.
# City number: 758 did not return data.
# City number: 759 did not return data.
# City number: 760 did not return data.
# City number: 761 did not return data.
# City number: 762 did not return data.
# City number: 763 did not return data.
# City number: 764 did not return data.
# City number: 765 did not return data.
# City number: 766 did not return data.
# City number: 767 did not return data.
# City number: 768  City name: Rio do Salto
# City number: 769 did not return data.
# City number: 770 did not return data.
# City number: 771  City name: Provincia del Pastaza
# City number: 772 did not return data.
# City number: 773 did not return data.
# City number: 774 did not return data.
# City number: 775  City name: Bo`ston Shahri
# City number: 776  City name: Shijiacun
# City number: 777  City name: Graafwater
# City number: 778  City name: Makarov
# City number: 779 did not return data.
# City number: 780  City name: Zelenoborsk
# City number: 781 did not return data.
# City number: 782 did not return data.
# City number: 783  City name: Curry
# City number: 784  City name: Aleutians West
# City number: 785 did not return data.
# City number: 786 did not return data.
# City number: 787 did not return data.
# City number: 788 did not return data.
# City number: 789 did not return data.
# City number: 790  City name: Phanom
# City number: 791 did not return data.
# City number: 792  City name: Chamnanga
# City number: 793 did not return data.
# City number: 794  City name: Mayo
# City number: 795 did not return data.
# City number: 796  City name: Colville Lake
# City number: 797  City name: Seymour
# City number: 798 did not return data.
# City number: 799 did not return data.
# City number: 800  City name: Hinton
# City number: 801 did not return data.
# City number: 802  City name: Alto Parnaíba
# City number: 803 did not return data.
# City number: 804 did not return data.
# City number: 805 did not return data.
# City number: 806 did not return data.
# City number: 807  City name: Talas
# City number: 808  City name: Langfang
# City number: 809 did not return data.
# City number: 810  City name: Atammik
# City number: 811 did not return data.
# City number: 812 did not return data.
# City number: 813 did not return data.
# City number: 814  City name: Chisasibi
# City number: 815 did not return data.
# City number: 816  City name: Svetlyy
# City number: 817 did not return data.
# City number: 818 did not return data.
# City number: 819 did not return data.
# City number: 820 did not return data.
# City number: 821 did not return data.
# City number: 822 did not return data.
# City number: 823 did not return data.
# City number: 824 did not return data.
# City number: 825 did not return data.
# City number: 826 did not return data.
# City number: 827  City name: Swan River
# City number: 828  City name: Carbonita
# City number: 829  City name: Garissa
# City number: 830 did not return data.
# City number: 831  City name: Kushoky
# City number: 832 did not return data.
# City number: 833 did not return data.
# City number: 834 did not return data.
# City number: 835  City name: Kozyrëvsk
# City number: 836  City name: Ciudad Insurgentes
# City number: 837  City name: Don Luan
# City number: 838  City name: Baykalovsk
# City number: 839 did not return data.
# City number: 840  City name: Hiroo
# City number: 841 did not return data.
# City number: 842 did not return data.
# City number: 843 did not return data.
# City number: 844 did not return data.
# City number: 845  City name: Luanda
# City number: 846 did not return data.
# City number: 847 did not return data.
# City number: 848 did not return data.
# City number: 849 did not return data.
# City number: 850  City name: Majadas
# City number: 851 did not return data.
# City number: 852 did not return data.
# City number: 853 did not return data.
# City number: 854 did not return data.
# City number: 855 did not return data.
# City number: 856 did not return data.
# City number: 857 did not return data.
# City number: 858 did not return data.
# City number: 859  City name: Duck Village
# City number: 860 did not return data.
# City number: 861 did not return data.
# City number: 862  City name: San
# City number: 863 did not return data.
# City number: 864  City name: Ust'-Karsk
# City number: 865 did not return data.
# City number: 866 did not return data.
# City number: 867  City name: Kingman
# City number: 868  City name: Colonia San Pedro
# City number: 869 did not return data.
# City number: 870 did not return data.
# City number: 871 did not return data.
# City number: 872  City name: Qaraton
# City number: 873 did not return data.
# City number: 874 did not return data.
# City number: 875 did not return data.
# City number: 876 did not return data.
# City number: 877 did not return data.
# City number: 878 did not return data.
# City number: 879 did not return data.
# City number: 880  City name: Evjen
# City number: 881 did not return data.
# City number: 882 did not return data.
# City number: 883 did not return data.
# City number: 884 did not return data.
# City number: 885 did not return data.
# City number: 886 did not return data.
# City number: 887  City name: Rumung Municipality
# City number: 888 did not return data.
# City number: 889 did not return data.
# City number: 890 did not return data.
# City number: 891 did not return data.
# City number: 892  City name: Kaktovik
# City number: 893 did not return data.
# City number: 894 did not return data.
# City number: 895 did not return data.
# City number: 896 did not return data.
# City number: 897 did not return data.
# City number: 898 did not return data.
# City number: 899 did not return data.
# City number: 900 did not return data.
# City number: 901 did not return data.
# City number: 902  City name: Rādhanpur
# City number: 903 did not return data.
# City number: 904 did not return data.
# City number: 905 did not return data.
# City number: 906  City name: Alandroal
# City number: 907 did not return data.
# City number: 908 did not return data.
# City number: 909 did not return data.
# City number: 910 did not return data.
# City number: 911 did not return data.
# City number: 912 did not return data.
# City number: 913 did not return data.
# City number: 914 did not return data.
# City number: 915 did not return data.
# City number: 916  City name: Labasa
# City number: 917 did not return data.
# City number: 918  City name: Shintō
# City number: 919 did not return data.
# City number: 920 did not return data.
# City number: 921 did not return data.
# City number: 922  City name: Feld am See
# City number: 923 did not return data.
# City number: 924  City name: Borodinskaya
# City number: 925 did not return data.
# City number: 926 did not return data.
# City number: 927 did not return data.
# City number: 928  City name: Davila
# City number: 929 did not return data.
# City number: 930 did not return data.
# City number: 931  City name: Lasengmiao
# City number: 932  City name: Chute-aux-Outardes
# City number: 933 did not return data.
# City number: 934 did not return data.
# City number: 935  City name: Chinchipe
# City number: 936 did not return data.
# City number: 937  City name: Horiult
# City number: 938 did not return data.
# City number: 939  City name: Mayumba
# City number: 940 did not return data.
# City number: 941 did not return data.
# City number: 942 did not return data.
# City number: 943 did not return data.
# City number: 944 did not return data.
# City number: 945 did not return data.
# City number: 946 did not return data.
# City number: 947  City name: Loyada
# City number: 948 did not return data.
# City number: 949 did not return data.
# City number: 950 did not return data.
# City number: 951 did not return data.
# City number: 952 did not return data.
# City number: 953 did not return data.
# City number: 954 did not return data.
# City number: 955  City name: Taksimo
# City number: 956 did not return data.
# City number: 957 did not return data.
# City number: 958  City name: La Cuesta
# City number: 959 did not return data.
# City number: 960  City name: La Plaine
# City number: 961  City name: Arctic Village
# City number: 962 did not return data.
# City number: 963 did not return data.
# City number: 964 did not return data.
# City number: 965  City name: Leilani Estates
# City number: 966  City name: Safende
# City number: 967 did not return data.
# City number: 968 did not return data.
# City number: 969 did not return data.
# City number: 970 did not return data.
# City number: 971  City name: Itaituba
# City number: 972  City name: Ning’an
# City number: 973 did not return data.
# City number: 974 did not return data.
# City number: 975  City name: Parkkino
# City number: 976 did not return data.
# City number: 977 did not return data.
# City number: 978 did not return data.
# City number: 979 did not return data.
# City number: 980  City name: Jinniu
# City number: 981 did not return data.
# City number: 982 did not return data.
# City number: 983 did not return data.
# City number: 984  City name: San Juan
# City number: 985 did not return data.
# City number: 986 did not return data.
# City number: 987 did not return data.
# City number: 988 did not return data.
# City number: 989  City name: Berdigestyakh
# City number: 990 did not return data.
# City number: 991 did not return data.
# City number: 992 did not return data.
# City number: 993 did not return data.
# City number: 994 did not return data.
# City number: 995 did not return data.
# City number: 996 did not return data.
# City number: 997 did not return data.
# City number: 998 did not return data.
# City number: 999 did not return data.
# City number: 1000 did not return data.
# City number: 1001 did not return data.
# City number: 1002 did not return data.
# City number: 1003 did not return data.
# City number: 1004 did not return data.
# City number: 1005 did not return data.
# City number: 1006 did not return data.
# City number: 1007 did not return data.
# City number: 1008 did not return data.
# City number: 1009 did not return data.
# City number: 1010 did not return data.
# City number: 1011 did not return data.
# City number: 1012 did not return data.
# City number: 1013 did not return data.
# City number: 1014 did not return data.
# City number: 1015 did not return data.
# City number: 1016  City name: Qümong
# City number: 1017  City name: Vao
# City number: 1018 did not return data.
# City number: 1019  City name: Zhoujiajing
# City number: 1020 did not return data.
# City number: 1021 did not return data.
# City number: 1022 did not return data.
# City number: 1023  City name: Arviat
# City number: 1024 did not return data.
# City number: 1025 did not return data.
# City number: 1026 did not return data.
# City number: 1027 did not return data.
# City number: 1028 did not return data.
# City number: 1029  City name: Jordan
# City number: 1030 did not return data.
# City number: 1031  City name: La Victoria
# City number: 1032 did not return data.
# City number: 1033 did not return data.
# City number: 1034 did not return data.
# City number: 1035  City name: Borkou Region
# City number: 1036 did not return data.
# City number: 1037  City name: Arapahoe
# City number: 1038 did not return data.
# City number: 1039 did not return data.
# City number: 1040  City name: Vilhelmina
# City number: 1041  City name: Vanavara
# City number: 1042 did not return data.
# City number: 1043 did not return data.
# City number: 1044 did not return data.
# City number: 1045  City name: Inukjuak
# City number: 1046 did not return data.
# City number: 1047  City name: São Vicente do Sul
# City number: 1048  City name: Cape Parry
# City number: 1049 did not return data.
# City number: 1050 did not return data.
# City number: 1051  City name: Tsiigehtchic
# City number: 1052 did not return data.
# City number: 1053  City name: Leningradskiy
# City number: 1054  City name: Bordj Omar Driss
# City number: 1055 did not return data.
# City number: 1056 did not return data.
# City number: 1057  City name: Esfarāyen
# City number: 1058 did not return data.
# City number: 1059  City name: Ennadai
# City number: 1060 did not return data.
# City number: 1061 did not return data.
# City number: 1062  City name: Urubichá
# City number: 1063  City name: Ostrovnoy
# City number: 1064 did not return data.
# City number: 1065 did not return data.
# City number: 1066 did not return data.
# City number: 1067 did not return data.
# City number: 1068  City name: Ouakam
# City number: 1069  City name: Ngidihopitonu
# City number: 1070 did not return data.
# City number: 1071 did not return data.
# City number: 1072 did not return data.
# City number: 1073  City name: Sintang
# City number: 1074 did not return data.
# City number: 1075 did not return data.
# City number: 1076  City name: Schefferville
# City number: 1077 did not return data.
# City number: 1078  City name: San Ramón
# City number: 1079 did not return data.
# City number: 1080 did not return data.
# City number: 1081 did not return data.
# City number: 1082 did not return data.
# City number: 1083 did not return data.
# City number: 1084 did not return data.
# City number: 1085  City name: Frontera
# City number: 1086 did not return data.
# City number: 1087 did not return data.
# City number: 1088 did not return data.
# City number: 1089  City name: Gooty
# City number: 1090  City name: Guelmim-Es Semara
# City number: 1091 did not return data.
# City number: 1092 did not return data.
# City number: 1093 did not return data.
# City number: 1094  City name: Hadjer-Lamis Region
# City number: 1095 did not return data.
# City number: 1096  City name: Noyabrsk
# City number: 1097  City name: Beba Veche
# City number: 1098  City name: Sharm el Sheikh
# City number: 1099  City name: Tanah Merah
# City number: 1100 did not return data.
# City number: 1101  City name: Shouchun
# City number: 1102 did not return data.
# City number: 1103 did not return data.
# City number: 1104 did not return data.
# City number: 1105 did not return data.
# City number: 1106 did not return data.
# City number: 1107  City name: Ravensthorpe
# City number: 1108 did not return data.
# City number: 1109 did not return data.
# City number: 1110 did not return data.
# City number: 1111  City name: Port-Gentil
# City number: 1112 did not return data.
# City number: 1113 did not return data.
# City number: 1114 did not return data.
# City number: 1115 did not return data.
# City number: 1116 did not return data.
# City number: 1117 did not return data.
# City number: 1118  City name: Saint Mary's County
# City number: 1119  City name: Wiang Sa
# City number: 1120  City name: Yovon
# City number: 1121 did not return data.
# City number: 1122 did not return data.
# City number: 1123  City name: Wiluna
# City number: 1124  City name: Al Khasamah
# City number: 1125 did not return data.
# City number: 1126  City name: Bukomansimbi
# City number: 1127 did not return data.
# City number: 1128  City name: Kolbasa
# City number: 1129 did not return data.
# City number: 1130  City name: Primorskiy (Maritime) Kray
# City number: 1131 did not return data.
# City number: 1132 did not return data.
# City number: 1133  City name: Russia
# City number: 1134 did not return data.
# City number: 1135 did not return data.
# City number: 1136  City name: Fujishiro
# City number: 1137 did not return data.
# City number: 1138 did not return data.
# City number: 1139 did not return data.
# City number: 1140 did not return data.
# City number: 1141 did not return data.
# City number: 1142  City name: Tacuarembó
# City number: 1143 did not return data.
# City number: 1144 did not return data.
# City number: 1145  City name: Springhill
# City number: 1146  City name: Alamar
# City number: 1147 did not return data.
# City number: 1148  City name: Jervis Bay Territory
# City number: 1149 did not return data.
# City number: 1150  City name: Yermentau
# City number: 1151 did not return data.
# City number: 1152  City name: Ayan
# City number: 1153  City name: Qasigiannguit
# City number: 1154 did not return data.
# City number: 1155  City name: Hafar Al-Batin
# City number: 1156 did not return data.
# City number: 1157  City name: Norfolk Island
# City number: 1158 did not return data.
# City number: 1159 did not return data.
# City number: 1160  City name: Harian
# City number: 1161 did not return data.
# City number: 1162 did not return data.
# City number: 1163 did not return data.
# City number: 1164 did not return data.
# City number: 1165 did not return data.
# City number: 1166 did not return data.
# City number: 1167 did not return data.
# City number: 1168 did not return data.
# City number: 1169 did not return data.
# City number: 1170  City name: Evensk
# City number: 1171 did not return data.
# City number: 1172  City name: Bouza
# City number: 1173 did not return data.
# City number: 1174 did not return data.
# City number: 1175  City name: Perryton
# City number: 1176 did not return data.
# City number: 1177 did not return data.
# City number: 1178  City name: Al Madīnah al Munawwarah
# City number: 1179 did not return data.
# City number: 1180  City name: Demerval Lobão
# City number: 1181  City name: Bor
# City number: 1182  City name: Igloolik
# City number: 1183  City name: Kimberly
# City number: 1184  City name: Angelina
# City number: 1185 did not return data.
# City number: 1186 did not return data.
# City number: 1187  City name: Adamantina
# City number: 1188 did not return data.
# City number: 1189  City name: Keremeos
# City number: 1190 did not return data.
# City number: 1191 did not return data.
# City number: 1192 did not return data.
# City number: 1193  City name: Umba
# City number: 1194  City name: Whittier
# City number: 1195 did not return data.
# City number: 1196  City name: Kimmirut
# City number: 1197 did not return data.
# City number: 1198  City name: Maple Creek
# City number: 1199 did not return data.
# City number: 1200 did not return data.
# City number: 1201 did not return data.
# City number: 1202 did not return data.
# City number: 1203 did not return data.
# City number: 1204  City name: Kerema
# City number: 1205 did not return data.
# City number: 1206 did not return data.
# City number: 1207 did not return data.
# City number: 1208 did not return data.
# City number: 1209  City name: Easton
# City number: 1210 did not return data.
# City number: 1211 did not return data.
# City number: 1212  City name: Entuziastov
# City number: 1213 did not return data.
# City number: 1214 did not return data.
# City number: 1215 did not return data.
# City number: 1216 did not return data.
# City number: 1217  City name: Orda
# City number: 1218 did not return data.
# City number: 1219 did not return data.
# City number: 1220 did not return data.
# City number: 1221 did not return data.
# City number: 1222  City name: Darovskoy
# City number: 1223 did not return data.
# City number: 1224  City name: Verona
# City number: 1225 did not return data.
# City number: 1226  City name: Gari
# City number: 1227  City name: Haapiti
# City number: 1228 did not return data.
# City number: 1229 did not return data.
# City number: 1230  City name: Altai Krai
# City number: 1231 did not return data.
# City number: 1232 did not return data.
# City number: 1233 did not return data.
# City number: 1234 did not return data.
# City number: 1235 did not return data.
# City number: 1236  City name: Chanat-la-Mouteyre
# City number: 1237  City name: Bermejo
# City number: 1238 did not return data.
# City number: 1239  City name: South Padre Island
# City number: 1240 did not return data.
# City number: 1241  City name: Bandundu Province
# City number: 1242 did not return data.
# City number: 1243  City name: Linville
# City number: 1244 did not return data.
# ...
# City number: 1597  City name: Arzak
# City number: 1598 did not return data.
# City number: 1599 did not return data.
# City number: 1600 did not return data.
# City number: 1601 did not return data.
# City number: 1602  City name: Long Spruce
# City number: 1603 did not return data.
# City number: 1604 did not return data.
# City number: 1605 did not return data.
# City number: 1606  City name: North Slope
# City number: 1607 did not return data.
# City number: 1608  City name: Kosh-Agach
# City number: 1609  City name: Bissett
# City number: 1610 did not return data.
# City number: 1611 did not return data.
# City number: 1612  City name: Itzer
# City number: 1613 did not return data.
# City number: 1614 did not return data.
# City number: 1615 did not return data.
# City number: 1616 did not return data.
# City number: 1617 did not return data.
# City number: 1618 did not return data.
# City number: 1619  City name: Ash Shatt
# City number: 1620  City name: Jingpeng
# City number: 1621  City name: Puerto Rondón
# City number: 1622 did not return data.
# City number: 1623 did not return data.
# City number: 1624 did not return data.
# City number: 1625 did not return data.
# City number: 1626 did not return data.
# City number: 1627 did not return data.
# City number: 1628 did not return data.
# City number: 1629 did not return data.
# City number: 1630 did not return data.
# City number: 1631 did not return data.
# City number: 1632 did not return data.
# City number: 1633  City name: Kinosis
# City number: 1634  City name: Huanan
# City number: 1635 did not return data.
# City number: 1636  City name: Victoria Daly
# City number: 1637  City name: Dū Qal‘ah
# City number: 1638 did not return data.
# City number: 1639 did not return data.
# City number: 1640  City name: Akutan
# City number: 1641  City name: Moomba
# City number: 1642 did not return data.
# City number: 1643 did not return data.
# City number: 1644  City name: Onoun
# City number: 1645  City name: Rowan Bay
# City number: 1646 did not return data.
# City number: 1647 did not return data.
# City number: 1648  City name: Bongak
# City number: 1649 did not return data.
# City number: 1650 did not return data.
# City number: 1651 did not return data.
# City number: 1652 did not return data.
# City number: 1653 did not return data.
# City number: 1654  City name: Krasavino
# City number: 1655 did not return data.
# City number: 1656 did not return data.
# City number: 1657 did not return data.
# City number: 1658  City name: Port au Choix
# City number: 1659 did not return data.
# City number: 1660 did not return data.
# City number: 1661 did not return data.
# City number: 1662  City name: Mato Grosso
# City number: 1663  City name: Cherskiy
# City number: 1664 did not return data.
# City number: 1665 did not return data.
# City number: 1666 did not return data.
# City number: 1667  City name: West Coast
# City number: 1668 did not return data.
# City number: 1669  City name: Kangaamiut
# City number: 1670 did not return data.
# City number: 1671 did not return data.
# City number: 1672 did not return data.
# City number: 1673  City name: Ittoqqortoormiit
# City number: 1674  City name: Australia
# City number: 1675 did not return data.
# City number: 1676 did not return data.
# City number: 1677  City name: Chhātāpur
# City number: 1678 did not return data.
# City number: 1679 did not return data.
# City number: 1680 did not return data.
# City number: 1681 did not return data.
# City number: 1682 did not return data.
# City number: 1683 did not return data.
# City number: 1684 did not return data.
# City number: 1685 did not return data.
# City number: 1686  City name: South Caribbean Coast Autonomous Region
# City number: 1687 did not return data.
# City number: 1688  City name: Sali
# City number: 1689 did not return data.
# City number: 1690 did not return data.
# City number: 1691  City name: Nusa Dua
# City number: 1692 did not return data.
# City number: 1693 did not return data.
# City number: 1694  City name: Southport
# City number: 1695 did not return data.
# City number: 1696  City name: Lappajärvi
# City number: 1697 did not return data.
# City number: 1698  City name: Burwood
# City number: 1699 did not return data.
# City number: 1700 did not return data.
# City number: 1701  City name: Mitata
# City number: 1702 did not return data.
# City number: 1703 did not return data.
# City number: 1704  City name: Tazovsky
# City number: 1705  City name: Saranpaul'
# City number: 1706  City name: Kununurra
# City number: 1707 did not return data.
# City number: 1708 did not return data.
# City number: 1709  City name: Bougainville
# City number: 1710 did not return data.
# City number: 1711  City name: Siete Palmas
# City number: 1712 did not return data.
# City number: 1713  City name: Marjah
# City number: 1714  City name: Autauga
# City number: 1715 did not return data.
# City number: 1716 did not return data.
# City number: 1717  City name: Novo Aripuanã
# City number: 1718 did not return data.
# City number: 1719  City name: Los Lagos Region
# City number: 1720 did not return data.
# City number: 1721  City name: Uzynkair
# City number: 1722 did not return data.
# City number: 1723 did not return data.
# City number: 1724 did not return data.
# City number: 1725 did not return data.
# City number: 1726  City name: Solnechnyy
# City number: 1727 did not return data.
# City number: 1728  City name: Olonkinbyen
# City number: 1729  City name: Huon Valley
# City number: 1730 did not return data.
# City number: 1731 did not return data.
# City number: 1732  City name: Chanika
# City number: 1733 did not return data.
# City number: 1734  City name: Dease Lake
# City number: 1735 did not return data.
# City number: 1736 did not return data.
# City number: 1737 did not return data.
# City number: 1738 did not return data.
# City number: 1739 did not return data.
# City number: 1740 did not return data.
# City number: 1741 did not return data.
# City number: 1742  City name: Sangkulirang
# City number: 1743 did not return data.
# City number: 1744 did not return data.
# City number: 1745 did not return data.
# City number: 1746 did not return data.
# City number: 1747 did not return data.
# City number: 1748  City name: Cedrillas
# City number: 1749  City name: Kargasok
# City number: 1750 did not return data.
# City number: 1751  City name: Ukungu
# City number: 1752 did not return data.
# City number: 1753 did not return data.
# City number: 1754  City name: Sudan
# City number: 1755 did not return data.
# City number: 1756  City name: Buntharik
# City number: 1757 did not return data.
# City number: 1758  City name: Duokake
# City number: 1759 did not return data.
# City number: 1760 did not return data.
# City number: 1761  City name: San Juan Province
# City number: 1762 did not return data.
# City number: 1763 did not return data.
# City number: 1764  City name: Frankfort
# City number: 1765  City name: Entuziastov
# City number: 1766  City name: Kalāteh-ye Dowlat
# City number: 1767 did not return data.
# City number: 1768 did not return data.
# City number: 1769 did not return data.
# City number: 1770 did not return data.
# City number: 1771 did not return data.
# City number: 1772 did not return data.
# City number: 1773 did not return data.
# City number: 1774 did not return data.
# City number: 1775 did not return data.
# City number: 1776 did not return data.
# City number: 1777 did not return data.
# City number: 1778  City name: Saule
# City number: 1779 did not return data.
# City number: 1780  City name: Oxelösund
# City number: 1781 did not return data.
# City number: 1782 did not return data.
# City number: 1783  City name: Melangguane
# City number: 1784 did not return data.
# City number: 1785 did not return data.
# City number: 1786 did not return data.
# City number: 1787  City name: Uummannaq
# City number: 1788 did not return data.
# City number: 1789 did not return data.
# City number: 1790 did not return data.
# City number: 1791 did not return data.
# City number: 1792 did not return data.
# City number: 1793 did not return data.
# City number: 1794 did not return data.
# City number: 1795 did not return data.
# City number: 1796 did not return data.
# City number: 1797 did not return data.
# City number: 1798 did not return data.
# City number: 1799 did not return data.
# City number: 1800 did not return data.
# City number: 1801 did not return data.
# City number: 1802  City name: Stornoway
# City number: 1803 did not return data.
# City number: 1804  City name: Byumba Ville
# City number: 1805  City name: Khapalu
# City number: 1806 did not return data.
# City number: 1807 did not return data.
# City number: 1808  City name: Laverton
# City number: 1809 did not return data.
# City number: 1810 did not return data.
# City number: 1811 did not return data.
# City number: 1812 did not return data.
# City number: 1813  City name: Ouanaminthe
# City number: 1814 did not return data.
# City number: 1815 did not return data.
# City number: 1816  City name: Gamba
# City number: 1817 did not return data.
# City number: 1818  City name: Quilpie
# City number: 1819 did not return data.
# City number: 1820  City name: Ankang
# City number: 1821  City name: Nizhnesortymskiy
# City number: 1822 did not return data.
# City number: 1823  City name: Nadym
# City number: 1824  City name: Simod
# City number: 1825 did not return data.
# City number: 1826 did not return data.
# City number: 1827 did not return data.
# City number: 1828 did not return data.
# City number: 1829  City name: Räpina
# City number: 1830  City name: Aral
# City number: 1831 did not return data.
# City number: 1832 did not return data.
# City number: 1833 did not return data.
# City number: 1834  City name: Beishanyanchi
# City number: 1835 did not return data.
# City number: 1836  City name: Southern Red Sea Region
# City number: 1837  City name: Cherskiy
# City number: 1838 did not return data.
# City number: 1839  City name: Kamativi Mine
# City number: 1840  City name: Mhango
# City number: 1841  City name: Bogashevo
# City number: 1842 did not return data.
# City number: 1843 did not return data.
# City number: 1844 did not return data.
# City number: 1845  City name: Craig
# City number: 1846  City name: Turaif
# City number: 1847 did not return data.
# City number: 1848  City name: Renews-Cappahayden
# City number: 1849  City name: Longcang
# City number: 1850 did not return data.
# City number: 1851 did not return data.
# City number: 1852 did not return data.
# City number: 1853 did not return data.
# City number: 1854 did not return data.
# City number: 1855  City name: Qal‘ah-ye Fārsī
# City number: 1856 did not return data.
# City number: 1857  City name: Formosa Province
# City number: 1858  City name: Jeff Davis
# City number: 1859 did not return data.
# City number: 1860 did not return data.
# City number: 1861  City name: Río Negro Province
# City number: 1862 did not return data.
# City number: 1863  City name: Moḩammadābād
# City number: 1864  City name: Sodankylä
# City number: 1865 did not return data.
# City number: 1866  City name: Boca do Acre
# City number: 1867  City name: Dzüünkharaa
# City number: 1868  City name: Dul'durga
# City number: 1869  City name: Chañaral
# City number: 1870  City name: North Aegean
# City number: 1871 did not return data.
# City number: 1872  City name: Røssvoll
# City number: 1873 did not return data.
# City number: 1874 did not return data.
# City number: 1875 did not return data.
# City number: 1876  City name: Carira
# City number: 1877  City name: Myrtle Beach
# City number: 1878 did not return data.
# City number: 1879  City name: Manati
# City number: 1880 did not return data.
# City number: 1881 did not return data.
# City number: 1882 did not return data.
# City number: 1883 did not return data.
# City number: 1884  City name: Alcuéscar
# City number: 1885  City name: Saquena
# City number: 1886  City name: Adak
# City number: 1887 did not return data.
# City number: 1888 did not return data.
# City number: 1889 did not return data.
# City number: 1890  City name: French Polynesia
# City number: 1891  City name: Ilo
# City number: 1892  City name: Mejillones
# City number: 1893  City name: Khuzhir
# City number: 1894  City name: Yellowknife
# City number: 1895  City name: Abou el Hassan
# City number: 1896 did not return data.
# City number: 1897  City name: Tucano
# City number: 1898 did not return data.
# City number: 1899  City name: Greenland
# City number: 1900 did not return data.
# City number: 1901  City name: Reguiba
# City number: 1902 did not return data.
# City number: 1903 did not return data.
# City number: 1904 did not return data.
# City number: 1905 did not return data.
# City number: 1906 did not return data.
# City number: 1907 did not return data.
# City number: 1908 did not return data.
# City number: 1909 did not return data.
# City number: 1910 did not return data.
# City number: 1911  City name: Kapit
# City number: 1912 did not return data.
# City number: 1913 did not return data.
# City number: 1914 did not return data.
# City number: 1915  City name: Chatsworth
# City number: 1916 did not return data.
# City number: 1917 did not return data.
# City number: 1918 did not return data.
# City number: 1919 did not return data.
# City number: 1920 did not return data.
# City number: 1921 did not return data.
# City number: 1922 did not return data.
# City number: 1923 did not return data.
# City number: 1924 did not return data.
# City number: 1925  City name: Svetlaya
# City number: 1926 did not return data.
# City number: 1927 did not return data.
# City number: 1928 did not return data.
# City number: 1929 did not return data.
# City number: 1930 did not return data.
# City number: 1931 did not return data.
# City number: 1932  City name: Kangaamiut
# City number: 1933  City name: Ust'-Kamchatsk
# City number: 1934  City name: Tawstock
# City number: 1935 did not return data.
# City number: 1936 did not return data.
# City number: 1937  City name: Evensk
# City number: 1938  City name: Puyang Chengguanzhen
# City number: 1939 did not return data.
# City number: 1940 did not return data.
# City number: 1941  City name: Chipata
# City number: 1942 did not return data.
# City number: 1943 did not return data.
# City number: 1944 did not return data.
# City number: 1945 did not return data.
# City number: 1946 did not return data.
# City number: 1947 did not return data.
# City number: 1948 did not return data.
# City number: 1949  City name: Ostrov
# City number: 1950 did not return data.
# City number: 1951  City name: Yuanquan
# City number: 1952 did not return data.
# City number: 1953 did not return data.
# City number: 1954 did not return data.
# City number: 1955 did not return data.
# City number: 1956 did not return data.
# City number: 1957 did not return data.
# City number: 1958  City name: Jonglei
# City number: 1959  City name: Benguela Province
# City number: 1960 did not return data.
# City number: 1961 did not return data.
# City number: 1962 did not return data.
# City number: 1963  City name: Tafresh
# City number: 1964  City name: Rikitea
# City number: 1965  City name: Ust-Maya
# City number: 1966 did not return data.
# City number: 1967 did not return data.
# City number: 1968 did not return data.
# City number: 1969 did not return data.
# City number: 1970  City name: Upper Nile
# City number: 1971 did not return data.
# City number: 1972  City name: Con Son
# City number: 1973 did not return data.
# City number: 1974 did not return data.
# City number: 1975  City name: Bayganin
# City number: 1976 did not return data.
# City number: 1977  City name: Neltume
# City number: 1978 did not return data.
# City number: 1979  City name: Eastend
# City number: 1980  City name: Salina
# City number: 1981  City name: Daşoguz Welaýaty
# City number: 1982 did not return data.
# City number: 1983 did not return data.
# City number: 1984 did not return data.
# City number: 1985  City name: Unionville
# City number: 1986  City name: Tauramena
# City number: 1987 did not return data.
# City number: 1988 did not return data.
# City number: 1989 did not return data.
# City number: 1990 did not return data.
# City number: 1991 did not return data.
# City number: 1992 did not return data.
# City number: 1993 did not return data.
# City number: 1994  City name: Mama
# City number: 1995 did not return data.
# City number: 1996  City name: Wad Medani
# City number: 1997 did not return data.
# City number: 1998 did not return data.
# City number: 1999  City name: Edinburgh of the Seven Seas
# City number: 2000 did not return data.

# %% [markdown]
# ### Convert cities weather log to a pandas DataFrame and export to csv

# %%
df = pd.DataFrame(cities_weather_log)

df.to_csv("Cities Weather Log.csv")

df.head()
# Out:
#         City Country  Latitude  Longitude Current Temperature  Humidity  \
# 0      Ozona      US     30.40    -101.04                73.3        64
# 1  Seyfūllīn      KZ     53.44      68.94                45.3        87
# 2    Sesheke      ZM    -17.13      24.75                68.8        34
# 3      Mweka      CD     -4.52      21.44                69.4        99
# 4      Bowen      AR    -34.47     -67.10                64.7        28
#
#    Cloudiness  Wind Speed                 Date
# 0           1        4.10  2020-10-26 00:53:12
# 1         100        5.97  2020-10-26 00:53:12
# 2           0        1.49  2020-10-26 00:53:13
# 3         100        0.67  2020-10-26 00:53:13
# 4           0        2.61  2020-10-26 00:53:13

# %%
# Check dataset for common humidity typos - no issues found.
drop_list = df.loc[df.Humidity > 100].index
for x in drop_list:
    print(x)

# %% [markdown]
# ## Plot the data and observe how weather changes as we approach the equator (on October 24, 2020)

# %%
# Convert columns to numeric data type for plotting

df["Latitude"] = pd.to_numeric(df["Latitude"])
df["Current Temperature"] = pd.to_numeric(df["Current Temperature"])
df["Humidity"] = pd.to_numeric(df["Humidity"])
df["Cloudiness"] = pd.to_numeric(df["Cloudiness"])
df["Wind Speed"] = pd.to_numeric(df["Wind Speed"])

# %% [markdown]
# ## Current Temperature vs. Latitude
#  * Moving towards the equator, the current temperature predictably increases to a balmy 75 degrees Fahrenheit. Surprisingly, there are already three cities (far north and south) with a current temperature less than -10. This plot also illustrates that there are a lot of cities moving into the far northern latitudes, but not many cities in far south (due to lack of land mass).

# %%
# Scatter plot with matplotlib.pyplot

plt.scatter(df["Latitude"], df["Current Temperature"])
plt.title("Current Temperature vs. Latitude on "+ date)
plt.xlabel("Degrees Latitude")
plt.ylabel("Temperature in Fahrenheit")
plt.yticks([-25, 0, 25, 50, 75, 100, 125])
plt.axvline(0, c="gray")
plt.grid()
plt.savefig("Figures/Scatter plot temp vs lat.png")
plt.show()

# %% [markdown]
# ## %Humidity vs. Latitude
# * Moving towards the equator, %humidity is low around the tropics (+/-23.5 degrees) and abrubtly increases at +/-10 degrees. There is also an interesting dense cluster of far northern cities (potentially Canada, northern Europe, or northern Asia) with extremely high humidity.

# %%
# Scatter plot with matplotlib.pyplot

plt.scatter(df["Latitude"], df["Humidity"])
plt.title("Percent Humidity vs. Latitude on "+ date)
plt.xlabel("Degrees Latitude")
plt.ylabel("%Humidity")
plt.yticks([0, 25, 50, 75, 100])
plt.axvline(0, c="gray")
plt.grid()
plt.savefig("Figures/Scatter plot %humidity vs lat.png")
plt.show()

# %% [markdown]
# ## Cloudiness vs. Latitude
# * If cloudiness were plotted on a histogram, this would be a markedly bimodal distribution with many cities having clear skies and many cities having complete cloud cover. +/-10 degrees from the equator there are very few cities with clear skies and quite a few cities with dense cloud cover.

# %%
# Scatter plot with matplotlib.pyplot

plt.scatter(df["Latitude"], df["Cloudiness"])
plt.title("Cloudiness vs. Latitude on "+ date)
plt.xlabel("Degrees Latitude")
plt.ylabel("Cloudiness")
plt.yticks([0, 25, 50, 75, 100])
plt.axvline(0, c="gray")
plt.grid()
plt.savefig("Figures/Scatter plot cloudiness vs lat.png")
plt.show()

# %% [markdown]
# ## Wind Speed Plot vs. Latitude
# * As you move towards the equator, wind speed decreases, perhaps implying fewer storms.

# %%
# Scatter plot with matplotlib.pyplot

plt.scatter(df["Latitude"], df["Wind Speed"])
plt.title("Wind Speed vs. Latitude on "+ date)
plt.xlabel("Degrees Latitude")
plt.ylabel("Wind Speed-mph")
plt.yticks([0, 5, 10, 15, 20, 25])
plt.axvline(0, c="gray")
plt.grid()
plt.savefig("Figures/Scatter plot wind speed vs lat.png")
plt.show()

# %% [markdown]
# ## Linear Regression Analyses

# %%
# Select cities in northern hemisphere to use in the following analyses.
north_df = df.loc[df["Latitude"]>0]

# Select cities in southern hemisphere to use in the following analyses.
south_df = df.loc[df["Latitude"]<0]

# %% [markdown]
# ####  Temperature vs. Latitude (Northern Hemisphere)
# * The regression analysis confirms that proximity to the equator is a strong predictor of temperature and the results are highly statistically significant.

# %%
# Regression analysis with matplotlib.pyplot

plt.scatter(north_df["Latitude"], north_df["Current Temperature"])
plt.title("Current Temperature vs. Latitude on "+ date + " Northern Hemisphere")
plt.xlabel("Degrees Latitude")
plt.ylabel("Current Temperature-F")
plt.yticks([-25, 0, 25, 50, 75, 100, 125])
slope, y_int, r, p, std_err = sts.linregress(north_df["Latitude"], north_df["Current Temperature"])
predicted_temp = slope * north_df["Latitude"] + y_int
plt.plot(north_df["Latitude"], predicted_temp,"--", c="black")
plt.savefig("Figures/Regression analysis temp vs lat north.png")
plt.show()
print("y=" + str(round(slope, 1)) + "*x + " + str(round(y_int, 1)))
print("r=" + str(round(r, 2)))
print("p=" + str(round(p, 2)))
print("standard error= " + str(round(std_err, 2)))
# Out:
# y=-1.1*x + 90.1
# r=-0.86
# p=0.0
# standard error= 0.03

# %% [markdown]
# ####  Temperature vs. Latitude (Southern Hemisphere)
# * The regression analysis confirms that proximity to the equator is a strong predictor of temperature and the results are highly statistically significant. Though the data points in the southern hemisphere aren't as tightly clustered as in the northern hemisphere.

# %%
# Regression analysis with matplotlib.pyplot

plt.scatter(south_df["Latitude"], south_df["Current Temperature"])
plt.title("Current Temperature vs. Latitude on "+ date + " Southern Hemisphere")
plt.xlabel("Degrees Latitude")
plt.ylabel("Current Temperature-F")
plt.yticks([-25, 0, 25, 50, 75, 100, 125])
slope, y_int, r, p, std_err = sts.linregress(south_df["Latitude"], south_df["Current Temperature"])
predicted_temp = slope * south_df["Latitude"] + y_int
plt.plot(south_df["Latitude"], predicted_temp,"--", c="black")
plt.savefig("Figures/Regression analysis temp vs lat south.png")
plt.show()
print("y=" + str(round(slope, 1)) + "*x + " + str(round(y_int, 1)))
print("r=" + str(round(r, 2)))
print("p=" + str(round(p, 2)))
print("standard error= " + str(round(std_err, 2)))
# Out:
# y=0.6*x + 81.4
# r=0.61
# p=0.0
# standard error= 0.06

# %% [markdown]
# ####  %Humidity vs. Latitude (Northern Hemisphere)
# * The regression analysis shows that the humidity vs. latitude trend is weaker than the temperature trend, but still there and still highly statistically significant.

# %%
# Regression analysis with matplotlib.pyplot

plt.scatter(north_df["Latitude"], north_df["Humidity"])
plt.title("Humidity vs. Latitude on "+ date + " Northern Hemisphere")
plt.xlabel("Degrees Latitude")
plt.ylabel("%Humidity")
plt.yticks([-25, 0, 25, 50, 75, 100, 125])
slope, y_int, r, p, std_err = sts.linregress(north_df["Latitude"], north_df["Humidity"])
predicted_humidity = slope * north_df["Latitude"] + y_int
plt.plot(north_df["Latitude"], predicted_humidity,"--", c="black")
plt.savefig("Figures/Regression analysis %humidity vs lat north.png")
plt.show()
print("y=" + str(round(slope, 1)) + "*x + " + str(round(y_int, 1)))
print("r=" + str(round(r, 2)))
print("p=" + str(round(p, 2)))
print("standard error= " + str(round(std_err, 2)))
# Out:
# y=0.5*x + 57.2
# r=0.45
# p=0.0
# standard error= 0.04

# %% [markdown]
# ####  %Humidity vs. Latitude (Southern Hemisphere)
# * The regression analysis for the southern hemisphere on the other hand shows a very weak correlation between humidity and latitude and the result is not statistically significant.

# %%
# Regression analysis with matplotlib.pyplot

plt.scatter(south_df["Latitude"], south_df["Humidity"])
plt.title("Humidity vs. Latitude on "+ date + "Southern Hemisphere")
plt.xlabel("Degrees Latitude")
plt.ylabel("%Humidity")
plt.yticks([-25, 0, 25, 50, 75, 100, 125])
slope, y_int, r, p, std_err = sts.linregress(south_df["Latitude"], south_df["Humidity"])
predicted_humidity = slope * south_df["Latitude"] + y_int
plt.plot(south_df["Latitude"], predicted_humidity,"--", c="black")
plt.savefig("Figures/Regression analysis %humidity vs lat south.png")
plt.show()
print("y=" + str(round(slope, 1)) + "*x + " + str(round(y_int, 1)))
print("r=" + str(round(r, 2)))
print("p=" + str(round(p, 2)))
print("standard error= " + str(round(std_err, 2)))
# Out:
# y=0.6*x + 79.2
# r=0.34
# p=0.0
# standard error= 0.13

# %% [markdown]
# ####  %Cloudiness vs. Latitude (Northern Hemisphere)
# * In the northern hemisphere, the regression analysis shows that there is almost no increase in cloudiness as you move towards the equator and the result is not statistically significant and may have occurred by chance.

# %%
# Regression analysis with matplotlib.pyplot

plt.scatter(north_df["Latitude"], north_df["Cloudiness"])
plt.title("Cloudiness vs. Latitude on "+ date + " Northern Hemisphere")
plt.xlabel("Degrees Latitude")
plt.ylabel("%Cloudiness")
plt.yticks([-25, 0, 25, 50, 75, 100, 125])
slope, y_int, r, p, std_err = sts.linregress(north_df["Latitude"], north_df["Cloudiness"])
predicted_cloudiness = slope * north_df["Latitude"] + y_int
plt.plot(north_df["Latitude"], predicted_cloudiness,"--", c="black")
plt.savefig("Figures/Regression analysis %cloudiness vs lat north.png")
plt.show()
print("y=" + str(round(slope, 1)) + "*x + " + str(round(y_int, 1)))
print("r=" + str(round(r, 2)))
print("p=" + str(round(p, 2)))
print("standard error= " + str(round(std_err, 2)))
# Out:
# y=0.8*x + 24.8
# r=0.35
# p=0.0
# standard error= 0.09

# %% [markdown]
# ####  %Cloudiness vs. Latitude (Southern Hemisphere)
# * In the southern hemisphere, the regression analysis shows that there is almost no increase in cloudiness as you move towards the equator and the result is not statistically significant and may have occurred by chance.

# %%
# Regression analysis with matplotlib.pyplot

plt.scatter(south_df["Latitude"], south_df["Cloudiness"])
plt.title("Cloudiness vs. Latitude on "+ date + "Southern Hemisphere")
plt.xlabel("Degrees Latitude")
plt.ylabel("%Cloudiness")
plt.yticks([-25, 0, 25, 50, 75, 100, 125])
slope, y_int, r, p, std_err = sts.linregress(south_df["Latitude"], south_df["Cloudiness"])
predicted_cloudiness = slope * south_df["Latitude"] + y_int
plt.plot(south_df["Latitude"], predicted_cloudiness,"--", c="black")
plt.savefig("Figures/Regression analysis %cloudiness vs lat south.png")
plt.show()
print("y=" + str(round(slope, 1)) + "*x + " + str(round(y_int, 1)))
print("r=" + str(round(r, 2)))
print("p=" + str(round(p, 2)))
print("standard error= " + str(round(std_err, 2)))
# Out:
# y=0.8*x + 64.4
# r=0.24
# p=0.0
# standard error= 0.26

# %% [markdown]
# ####   Wind Speed vs. Latitude (Northern Hemisphere)
# * The regression results show that though there is almost no change in wind speed as you head north from the equator and that it is a statistically significant result.

# %%
# Regression analysis with matplotlib.pyplot

plt.scatter(north_df["Latitude"], north_df["Wind Speed"])
plt.title("Wind Speed vs. Latitude on "+ date + " Northern Hemisphere")
plt.xlabel("Degrees Latitude")
plt.ylabel("Wind Speed-mph")
plt.yticks([0, 25, 50])
slope, y_int, r, p, std_err = sts.linregress(north_df["Latitude"], north_df["Wind Speed"])
predicted_wind_speed = slope * north_df["Latitude"] + y_int
plt.plot(north_df["Latitude"], predicted_wind_speed,"--", c="black")
plt.savefig("Figures/Regression analysis wind speed vs lat north.png")
plt.show()
print("y=" + str(round(slope, 1)) + "*x + " + str(round(y_int, 1)))
print("r=" + str(round(r, 2)))
print("p=" + str(round(p, 2)))
print("standard error= " + str(round(std_err, 2)))
# Out:
# y=0.0*x + 3.0
# r=0.16
# p=0.0
# standard error= 0.01

# %% [markdown]
# ####  Wind Speed vs. Latitude (Southern Hemisphere)
# * On the other hand, as you move south away from the equator, the wind picks up slightly and it is a highly statistically significant result.

# %%
# Regression analysis with matplotlib.pyplot

plt.scatter(south_df["Latitude"], south_df["Wind Speed"])
plt.title("Wind Speed vs. Latitude on "+ date + "Southern Hemisphere")
plt.xlabel("Degrees Latitude")
plt.ylabel("Wind Speed-mph")
plt.yticks([-25, 0, 25, 50, 75, 100, 125])
slope, y_int, r, p, std_err = sts.linregress(south_df["Latitude"], south_df["Wind Speed"])
predicted_wind_speed = slope * south_df["Latitude"] + y_int
plt.plot(south_df["Latitude"], predicted_wind_speed,"--", c="black")
plt.savefig("Figures/Regression analysis wind speed vs lat south.png")
plt.show()
print("y=" + str(round(slope, 1)) + "*x + " + str(round(y_int, 1)))
print("r=" + str(round(r, 2)))
print("p=" + str(round(p, 2)))
print("standard error= " + str(round(std_err, 2)))
# Out:
# y=-0.1*x + 2.0
# r=-0.41
# p=0.0
# standard error= 0.02
